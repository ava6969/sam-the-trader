# %%
from backtest import BackTestPlot
import os
import pandas as pd
import glob
import matplotlib
import matplotlib.pyplot as plt
import evaluate
import plotly.graph_objects as go
import chart_studio.plotly as py
# %matplotlib inline

# %%
py.sign_in('ava6969', 'WD9W9LJsmNBSJTgIhh8v')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% height:100%; !important; }</style>"))
# Out:
# <style>.container { width:100% height:100%; !important; }</style>

# %%
files, acc_value, actions, result  = evaluate.update_data()
# Out:
# 18it [00:25,  1.43s/it]

# %%
res_s = result.nlargest(5, 'Sharpe ratio')

# %%
res_r = result.nlargest(5, 'Annual return')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(res_s)
# Out:
#     Alpha  Annual return  Annual volatility  Beta  Calmar ratio  \
# 3     0.0       7.027639           0.741789   1.0     11.953079
# 15    0.0       7.010987           0.741601   1.0     11.903689
# 16    0.0       6.916994           0.738113   1.0     11.752200
# 1     0.0       6.866089           0.735462   1.0     11.678151
# 10    0.0       0.102962           0.040355   1.0      5.133295
#
#     Cumulative returns  Daily value at risk  H_MAX  Initial Amount  \
# 3             7.719351            -0.084043    3.0         25000.0
# 15            7.700547            -0.084028    3.0         25000.0
# 16            7.594438            -0.083646    3.0         25000.0
# 1             7.536991            -0.083346    3.0         25000.0
# 10            0.126369            -0.004691    3.0         25000.0
#
#     Max drawdown  Omega ratio  Sharpe ratio  Sortino ratio  Stability  \
# 3      -0.587935     1.803862      3.197958       5.273827   0.907137
# 15     -0.588976     1.801925      3.195789       5.267439   0.906833
# 16     -0.588570     1.799988      3.191370       5.252310   0.906456
# 1      -0.587943     1.801607      3.191242       5.260759   0.905521
# 10     -0.020058     1.710085      2.456914       4.323838   0.936731
#
#     Tail ratio TickTraded  checkpoint  mean_reward
# 3     1.323126       TSLA       260.0     -13.1597
# 15    1.328146       TSLA        60.0     344.9172
# 16    1.324661       TSLA        40.0     429.7249
# 1     1.315298       TSLA        40.0    -330.9618
# 10    1.417299       AAPL        20.0    -151.5105

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(res_r)
# Out:
#     Alpha  Annual return  Annual volatility  Beta  Calmar ratio  \
# 3     0.0       7.027639           0.741789   1.0     11.953079
# 15    0.0       7.010987           0.741601   1.0     11.903689
# 16    0.0       6.916994           0.738113   1.0     11.752200
# 1     0.0       6.866089           0.735462   1.0     11.678151
# 5     0.0       0.899141           0.316722   1.0      2.934483
#
#     Cumulative returns  Daily value at risk  H_MAX  Initial Amount  \
# 3             7.719351            -0.084043    3.0         25000.0
# 15            7.700547            -0.084028    3.0         25000.0
# 16            7.594438            -0.083646    3.0         25000.0
# 1             7.536991            -0.083346    3.0         25000.0
# 5             1.178953            -0.037147    3.0         25000.0
#
#     Max drawdown  Omega ratio  Sharpe ratio  Sortino ratio  Stability  \
# 3      -0.587935     1.803862      3.197958       5.273827   0.907137
# 15     -0.588976     1.801925      3.195789       5.267439   0.906833
# 16     -0.588570     1.799988      3.191370       5.252310   0.906456
# 1      -0.587943     1.801607      3.191242       5.260759   0.905521
# 5      -0.306405     1.500982      2.192716       3.274292   0.821168
#
#     Tail ratio TickTraded  checkpoint  mean_reward
# 3     1.323126       TSLA       260.0     -13.1597
# 15    1.328146       TSLA        60.0     344.9172
# 16    1.324661       TSLA        40.0     429.7249
# 1     1.315298       TSLA        40.0    -330.9618
# 5     1.186317       AAPL       120.0      -9.0966

# %%
choice = 15

# %% [markdown]
# # Check Specific Checkpoint

# %%
result[result.checkpoint == 120.0]
# Out:
#     Alpha  Annual return  Annual volatility  Beta  Calmar ratio  \
# 5     0.0       0.899141           0.316722   1.0      2.934483
# 13    0.0       0.887858           0.316297   1.0      2.889332
#
#     Cumulative returns  Daily value at risk  H_MAX  Initial Amount  \
# 5             1.178953            -0.037147    3.0         25000.0
# 13            1.163245            -0.037118    3.0         25000.0
#
#     Max drawdown  Omega ratio  Sharpe ratio  Sortino ratio  Stability  \
# 5      -0.306405     1.500982      2.192716       3.274292   0.821168
# 13     -0.307288     1.497232      2.176270       3.249736   0.820019
#
#     Tail ratio TickTraded  checkpoint  mean_reward
# 5     1.186317       AAPL       120.0      -9.0966
# 13    1.181947       AAPL       120.0      13.8445

# %% [markdown]
# # Plot Actions and ClosePrice

# %%
df_action_value = actions[choice]

# %%
df_action_value.drop('date', axis=1, inplace=True)

# %%
df_action_value
# Out:
#         actions  close_price
# 0           0.0       66.280
# 1           0.0       66.300
# 2          -3.0       66.376
# 3          -1.0       66.300
# 4           2.0       66.128
# ...         ...          ...
# 182970      2.0      581.500
# 182971     -1.0      581.600
# 182972      2.0      582.000
# 182973      3.0      582.290
# 182974      2.0      582.200
#
# [182975 rows x 2 columns]

# %%
buys = df_action_value.loc[df_action_value['actions'] > 0]
sells = df_action_value.loc[df_action_value['actions'] < 0]

# %%
# fig = go.Figure(data=go.Data(line))
import plotly.express as px
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scattergl(x=df_action_value.index.values, y=df_action_value.close_price.values, mode='lines'))
fig.add_trace(go.Scattergl(x=buys.index, y=buys.close_price, name = 'buy signal',
                         mode='markers', marker = dict(color='red', symbol='y-up')))
fig.add_trace(go.Scattergl(x=sells.index, y=sells.close_price, name='sell signal',
                         mode='markers', marker = dict(color='green', symbol='y-down')))

py.plot(fig)

# %% [markdown]
# # Backtest

# %%
df_account_value = acc_value[choice]
df_account_value
# Out:
#           date  account_value
# 0   2019-12-02   25055.923952
# 1   2019-12-03   25107.249366
# 2   2019-12-04   25101.609514
# 3   2019-12-05   24778.207570
# 4   2019-12-06   25194.806715
# ..         ...            ...
# 257 2020-11-25  209285.396157
# 258 2020-11-26  213596.442466
# 259 2020-11-27  216231.093757
# 260 2020-11-30  217818.973516
# 261 2020-12-01  218000.253388
#
# [262 rows x 2 columns]

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 100em; }</style>"))
BackTestPlot(account_value=df_account_value, baseline_ticker = 'AAPL',
             baseline_start=df_account_value.iloc[0].date,
             baseline_end=df_account_value.iloc[-1].date,
            )
# Out:
# <style>div.output_scroll { height: 100em; }</style>
# annual return:  957.9587207418604
# sharpe ratio:  3.1957890154167368
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (252, 7)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-12-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-11-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>11</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>610.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>567.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>76.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.96</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>10.37</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-58.9%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.71</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>4.85</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.05</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.17</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-8.7%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>8.54</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>58.90</td>
#       <td>2020-02-25</td>
#       <td>2020-03-24</td>
#       <td>2020-06-16</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>29.29</td>
#       <td>2020-09-11</td>
#       <td>2020-09-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.97</td>
#       <td>2020-02-07</td>
#       <td>2020-02-11</td>
#       <td>2020-02-25</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12.75</td>
#       <td>2020-07-30</td>
#       <td>2020-08-20</td>
#       <td>2020-08-25</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8.00</td>
#       <td>2020-07-22</td>
#       <td>2020-07-27</td>
#       <td>2020-07-30</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# /home/dewe/anaconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/tears.py:925: UserWarning:
#
# Passed returns do not overlap with anyinteresting times.

# %% [markdown]
# # Use with Caution
#  To delete checkpoint

# %%
import numpy as np
k = set(result.index.to_list()) - set(result.nlargest(20, 'Sharpe ratio').index.to_list())

# %%
# import os
# for i in k:
#     os.remove(files[i])
