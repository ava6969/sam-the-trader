# %%
import pandas as pd

# %%
perf = pd.read_pickle('pickles/buytsla.pickle') # read in perf DataFrame
perf
# Out:
#                            algo_volatility  algorithm_period_return alpha  \
# 2019-10-01 20:00:00+00:00              NaN                      0.0  None
# 2019-10-02 20:00:00+00:00              0.0                      0.0  None
# 2019-10-03 20:00:00+00:00              0.0                      0.0  None
# 2019-10-04 20:00:00+00:00              0.0                      0.0  None
# 2019-10-07 20:00:00+00:00              0.0                      0.0  None
# 2019-10-08 20:00:00+00:00              0.0                      0.0  None
# 2019-10-09 20:00:00+00:00              0.0                      0.0  None
# 2019-10-10 20:00:00+00:00              0.0                      0.0  None
# 2019-10-11 20:00:00+00:00              0.0                      0.0  None
# 2019-10-14 20:00:00+00:00              0.0                      0.0  None
# 2019-10-15 20:00:00+00:00              0.0                      0.0  None
# 2019-10-16 20:00:00+00:00              0.0                      0.0  None
# ...
